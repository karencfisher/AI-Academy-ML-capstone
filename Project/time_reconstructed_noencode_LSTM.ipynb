# %%
import pandas as pd
import os
import time

from tensorflow.keras.models import load_model
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

from LSTM.TR_preprocess import preprocess
from LSTM.LSTM_classifier import LSTMclf
from tools.tools import evaluate

# %% [markdown]
# #### Load training and test data sets

# %%
pos_train_path = os.path.join('Data', 'pos_train.csv')
pos_train = pd.read_csv(pos_train_path)

neg_train_path = os.path.join('Data', 'neg_train.csv')
neg_train = pd.read_csv(neg_train_path)

pos_test_path = os.path.join('Data', 'pos_test.csv')
pos_test = pd.read_csv(pos_test_path)

neg_test_path = os.path.join('Data', 'neg_test.csv')
neg_test = pd.read_csv(neg_test_path)

# %% [markdown]
# #### Preprocessing data
#
# Reconstructs data into regularly intervaled time sequences (10 minut intervals)

# %%
print('Preprocessing training data...')
train_data, train_labels = preprocess(pos_train, neg_train, encode=False)
input_shape = train_data.shape
print(f'Train data shape: {train_data.shape} train labels shape: {train_labels.shape}')

train_data = train_data.tolist()
train_labels = train_labels.tolist()

print('Preprocessing test data...')
test_data, test_labels = preprocess(pos_test, neg_test, encode=False)
print(f'Test data shape: {test_data.shape} test labels shape: {test_labels.shape}')

test_data = test_data.tolist()
test_labels = test_labels.tolist()
# Out:
# generate:   1%|          | 3/359 [00:00<00:13, 26.33it/s]
# Preprocessing training data...
# generate: 100%|██████████| 359/359 [00:10<00:00, 34.80it/s]
# generate: 100%|██████████| 357/357 [00:07<00:00, 47.81it/s]
# Train data shape: (716, 1334, 5) train labels shape: (716,)
# Preprocessing test data...
# generate: 100%|██████████| 37/37 [00:00<00:00, 54.68it/s]
# generate: 100%|██████████| 37/37 [00:00<00:00, 67.71it/s]
# Test data shape: (74, 1334, 5) test labels shape: (74,)

# %% [markdown]
# #### Instantiate LSTM model

# %%
clf = LSTMclf(input_shape)
clf.model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# masking (Masking)            (None, 1334, 5)           0
# _________________________________________________________________
# lstm (LSTM)                  (None, 200)               164800
# _________________________________________________________________
# dense (Dense)                (None, 1)                 201
# =================================================================
# Total params: 165,001
# Trainable params: 165,001
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### Train different batch sizes with 5-fold cross validation

# %%
batch_sizes = [32, 64, 128, 256]
results = []
start_time = time.time()
for batch_size in batch_sizes:
    print(f'Cross validation with batch size {batch_size}.')
    metrics = clf.trainCV(train_data, train_labels, 5, batch_size, 10)
    metrics['batch_size'] = batch_size
    results.append(metrics)

    model_path = os.path.join('./LSTM/results/tr_noencode_results', f'LSTM{batch_size}.h5')
    clf.model.save(model_path)

elapsed_time = time.time() - start_time
results_df = pd.DataFrame(results, columns=['batch_size', 'accuracy', 'precision', 
                                            'recall', 'f1', 'auc'])
hr = int(elapsed_time // 3600)
elapsed_time %= 3600
min = int(elapsed_time // 60)
sec = elapsed_time % 60
print(f'Total time: {hr:02d}:{min:02d}:{sec:0.2f}')

result_path = os.path.join('./LSTM/results/tr_noencode_results', 'results.csv')
results_df.to_csv(result_path)
results_df
# Out:
# Cross validation with batch size 32.
# Beginning training LSTM with 5-fold validation...
# Epoch 1/10
# 18/18 [==============================] - 98s 5s/step - loss: 0.6458 - accuracy: 0.6283
# Epoch 2/10
# 18/18 [==============================] - 90s 5s/step - loss: 0.6165 - accuracy: 0.6597
# Epoch 3/10
# 18/18 [==============================] - 88s 5s/step - loss: 0.5979 - accuracy: 0.6684
# Epoch 4/10
# 18/18 [==============================] - 88s 5s/step - loss: 0.5884 - accuracy: 0.6824
# Epoch 5/10
# 18/18 [==============================] - 88s 5s/step - loss: 0.5702 - accuracy: 0.7120
# 5/5 [==============================] - 67s 13s/step - loss: 0.4601 - accuracy: 0.7801
# Epoch 3/10
# 5/5 [==============================] - 67s 13s/step - loss: 0.5727 - accuracy: 0.6911
# Epoch 4/10
# 5/5 [==============================] - 67s 13s/step - loss: 0.5645 - accuracy: 0.6597
# Epoch 5/10
# 5/5 [==============================] - 67s 13s/step - loss: 0.5261 - accuracy: 0.7592
# Epoch 6/10
# 5/5 [==============================] - 65s 13s/step - loss: 0.5110 - accuracy: 0.7714
# Epoch 7/10
# 5/5 [==============================] - 65s 13s/step - loss: 0.4770 - accuracy: 0.8080
# Epoch 8/10
# 5/5 [==============================] - 66s 13s/step - loss: 0.4574 - accuracy: 0.7993
# Epoch 9/10
# 5/5 [==============================] - 66s 13s/step - loss: 0.4356 - accuracy: 0.8325
# Epoch 10/10
# 5/5 [==============================] - 65s 13s/step - loss: 0.4288 - accuracy: 0.8307
# 18/18 [==============================] - 14s 803ms/step - loss: 0.4157 - accuracy: 0.8534
# 5/5 [==============================] - 4s 738ms/step - loss: 0.7769 - accuracy: 0.6783
# Fold 4 Train:  85.34% Val:  67.83%
# Epoch 1/10
# 5/5 [==============================] - 66s 13s/step - loss: 0.4309 - accuracy: 0.8255
# Epoch 2/10
# 5/5 [==============================] - 66s 13s/step - loss: 0.3974 - accuracy: 0.8412
# Epoch 3/10
# 5/5 [==============================] - 65s 13s/step - loss: 0.3856 - accuracy: 0.8307
# Epoch 4/10
# 5/5 [==============================] - 65s 13s/step - loss: 0.3706 - accuracy: 0.8325
# Epoch 5/10
# 5/5 [==============================] - 67s 13s/step - loss: 0.3619 - accuracy: 0.8412
# Epoch 6/10
# 5/5 [==============================] - 66s 13s/step - loss: 0.3614 - accuracy: 0.8342
# Epoch 7/10
# 5/5 [==============================] - 65s 13s/step - loss: 0.3561 - accuracy: 0.8325
# Epoch 8/10
# 5/5 [==============================] - 65s 13s/step - loss: 0.3520 - accuracy: 0.8325
# Epoch 9/10
# 5/5 [==============================] - 65s 13s/step - loss: 0.3387 - accuracy: 0.8464
# Epoch 10/10
# 5/5 [==============================] - 65s 13s/step - loss: 0.3492 - accuracy: 0.8342
# 18/18 [==============================] - 15s 814ms/step - loss: 0.3451 - accuracy: 0.8220
# 5/5 [==============================] - 4s 729ms/step - loss: 0.8800 - accuracy: 0.7413
# Fold 5 Train:  82.20% Val:  74.13%
# Cross validation with batch size 256.
# Beginning training LSTM with 5-fold validation...
# Epoch 1/10
# 3/3 [==============================] - 49s 15s/step - loss: 0.6963 - accuracy: 0.5183
# Epoch 2/10
# 3/3 [==============================] - 48s 15s/step - loss: 0.6416 - accuracy: 0.6300
# Epoch 3/10
# 3/3 [==============================] - 47s 15s/step - loss: 0.6159 - accuracy: 0.6684
# Epoch 4/10
# 3/3 [==============================] - 48s 15s/step - loss: 0.6296 - accuracy: 0.6353
# Epoch 5/10
# 3/3 [==============================] - 48s 15s/step - loss: 0.6031 - accuracy: 0.6824
# Epoch 6/10
# 3/3 [==============================] - 48s 15s/step - loss: 0.5989 - accuracy: 0.6806
# Epoch 7/10
# 3/3 [==============================] - 49s 15s/step - loss: 0.5747 - accuracy: 0.6946
# Epoch 8/10
# 3/3 [==============================] - 49s 15s/step - loss: 0.5776 - accuracy: 0.6876
# Epoch 9/10
# 3/3 [==============================] - 50s 15s/step - loss: 0.5625 - accuracy: 0.7190
# Epoch 10/10
# 3/3 [==============================] - 50s 16s/step - loss: 0.5405 - accuracy: 0.7347
# 18/18 [==============================] - 20s 1s/step - loss: 0.5340 - accuracy: 0.7208
# 5/5 [==============================] - 5s 1s/step - loss: 0.9780 - accuracy: 0.2727
# Fold 1 Train:  72.08% Val:  27.27%
# Epoch 1/10
# 3/3 [==============================] - 50s 16s/step - loss: 0.5447 - accuracy: 0.7103
# Epoch 2/10
# 3/3 [==============================] - 52s 16s/step - loss: 0.5041 - accuracy: 0.7487
# Epoch 3/10
# 3/3 [==============================] - 53s 16s/step - loss: 0.5223 - accuracy: 0.7243
# Epoch 4/10
# 3/3 [==============================] - 54s 17s/step - loss: 0.4924 - accuracy: 0.7679
# Epoch 5/10
# 3/3 [==============================] - 54s 17s/step - loss: 0.4915 - accuracy: 0.7504
# Epoch 6/10
# 3/3 [==============================] - 55s 17s/step - loss: 0.4910 - accuracy: 0.7452
# Epoch 7/10
# 3/3 [==============================] - 56s 17s/step - loss: 0.4462 - accuracy: 0.7993
# Epoch 8/10
# 3/3 [==============================] - 55s 17s/step - loss: 0.4523 - accuracy: 0.7871
# Epoch 9/10
# 3/3 [==============================] - 56s 17s/step - loss: 0.4260 - accuracy: 0.7976
# Epoch 10/10
# 3/3 [==============================] - 57s 18s/step - loss: 0.4173 - accuracy: 0.8010
# 18/18 [==============================] - 22s 1s/step - loss: 0.4562 - accuracy: 0.7731
# 5/5 [==============================] - 6s 1s/step - loss: 0.9143 - accuracy: 0.5105
# Fold 2 Train:  77.31% Val:  51.05%
# Epoch 1/10
# 3/3 [==============================] - 59s 18s/step - loss: 0.5183 - accuracy: 0.7155
# Epoch 2/10
# 3/3 [==============================] - 60s 18s/step - loss: 0.5668 - accuracy: 0.7068
# Epoch 3/10
# 3/3 [==============================] - 61s 19s/step - loss: 0.5968 - accuracy: 0.6928
# Epoch 4/10
# 3/3 [==============================] - 61s 19s/step - loss: 0.5908 - accuracy: 0.6876
# Epoch 5/10
# 3/3 [==============================] - 62s 19s/step - loss: 0.5679 - accuracy: 0.6998
# Epoch 6/10
# 3/3 [==============================] - 64s 19s/step - loss: 0.5371 - accuracy: 0.7853
# Epoch 7/10
# 3/3 [==============================] - 64s 20s/step - loss: 0.5164 - accuracy: 0.7539
# Epoch 8/10
# 3/3 [==============================] - 63s 19s/step - loss: 0.4980 - accuracy: 0.7504
# Epoch 9/10
# 3/3 [==============================] - 65s 19s/step - loss: 0.4872 - accuracy: 0.7696
# Epoch 10/10
# 3/3 [==============================] - 66s 20s/step - loss: 0.4794 - accuracy: 0.7749
# 18/18 [==============================] - 24s 1s/step - loss: 0.4742 - accuracy: 0.7452
# 5/5 [==============================] - 6s 1s/step - loss: 0.5433 - accuracy: 0.7692
# Fold 3 Train:  74.52% Val:  76.92%
# Epoch 1/10
# 3/3 [==============================] - 66s 20s/step - loss: 0.4947 - accuracy: 0.7382
# Epoch 2/10
# 3/3 [==============================] - 65s 19s/step - loss: 0.4742 - accuracy: 0.7853
# Epoch 3/10
# 3/3 [==============================] - 65s 20s/step - loss: 0.4579 - accuracy: 0.7574
# Epoch 4/10
# 3/3 [==============================] - 64s 19s/step - loss: 0.4318 - accuracy: 0.7993
# Epoch 5/10
# 3/3 [==============================] - 65s 19s/step - loss: 0.4262 - accuracy: 0.8202
# Epoch 6/10
# 3/3 [==============================] - 64s 19s/step - loss: 0.4160 - accuracy: 0.8220
# Epoch 7/10
# 3/3 [==============================] - 65s 20s/step - loss: 0.3974 - accuracy: 0.8360
# Epoch 8/10
# 3/3 [==============================] - 65s 20s/step - loss: 0.3873 - accuracy: 0.8307
# Epoch 9/10
# 3/3 [==============================] - 64s 19s/step - loss: 0.4516 - accuracy: 0.7784
# Epoch 10/10
# 3/3 [==============================] - 66s 20s/step - loss: 0.4847 - accuracy: 0.7330
# 18/18 [==============================] - 26s 1s/step - loss: 0.4529 - accuracy: 0.7818
# 5/5 [==============================] - 7s 1s/step - loss: 0.8846 - accuracy: 0.4965
# Fold 4 Train:  78.18% Val:  49.65%
# Epoch 1/10
# 3/3 [==============================] - 68s 20s/step - loss: 0.4934 - accuracy: 0.7382
# Epoch 2/10
# 3/3 [==============================] - 67s 20s/step - loss: 0.4684 - accuracy: 0.7661
# Epoch 3/10
# 3/3 [==============================] - 67s 20s/step - loss: 0.4308 - accuracy: 0.7871
# Epoch 4/10
# 3/3 [==============================] - 66s 20s/step - loss: 0.3879 - accuracy: 0.8237
# Epoch 5/10
# 3/3 [==============================] - 68s 20s/step - loss: 0.3898 - accuracy: 0.8185
# Epoch 6/10
# 3/3 [==============================] - 67s 20s/step - loss: 0.3812 - accuracy: 0.8255
# Epoch 7/10
# 3/3 [==============================] - 67s 20s/step - loss: 0.3716 - accuracy: 0.8255
# Epoch 8/10
# 3/3 [==============================] - 68s 21s/step - loss: 0.3579 - accuracy: 0.8237
# Epoch 9/10
# 3/3 [==============================] - 69s 21s/step - loss: 0.3506 - accuracy: 0.8220
# Epoch 10/10
# 3/3 [==============================] - 68s 21s/step - loss: 0.3425 - accuracy: 0.8342
# 18/18 [==============================] - 25s 1s/step - loss: 0.3428 - accuracy: 0.8237
# 5/5 [==============================] - 7s 1s/step - loss: 0.7385 - accuracy: 0.7483
# Fold 5 Train:  82.37% Val:  74.83%
# Total time: 04:10:38.57
#    batch_size  accuracy  precision    recall        f1       auc
# 0          32  0.634965   0.676259  0.523677  0.590267  0.635434
# 1          64  0.462937   0.460815  0.409471  0.433628  0.463162
# 2         128  0.644755   0.685512  0.540390  0.604361  0.645195
# 3         256  0.559441   0.579137  0.448468  0.505495  0.559908

# %% [markdown]
# #### Evaluate selected model
#
# We will pick the best of the four trained above, and use it to predict on the test data.

# %%
model_path = os.path.join('./LSTM/results/tr_noencode_results', 'LSTM128.h5')
clf = load_model(model_path, compile=False)

pred = clf.predict(test_data).reshape(-1)
pred = (pred > 0.5).astype(int)
metrics = evaluate(test_labels, pred)

print(classification_report(test_labels, pred))
cm = confusion_matrix(test_labels, pred)
sns.heatmap(cm, annot=True, fmt='d', cbar=False)
plt.title('Confusion Matrix')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.86      0.84        37
#            1       0.86      0.81      0.83        37
#
#     accuracy                           0.84        74
#    macro avg       0.84      0.84      0.84        74
# weighted avg       0.84      0.84      0.84        74
